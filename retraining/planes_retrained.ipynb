# %% [markdown]
# # **Bước 1:** Mount Drive và Khai báo các đường dẫn

# %%
from google.colab import drive
import os, shutil

if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATASET_NAME = "planes_128"
ZIP_FILE = f"{DATASET_NAME}.zip"
DRIVE_PATH = f"/content/drive/MyDrive/HyperNeRFGAN/data/{ZIP_FILE}"
LOCAL_PATH = f"/content/{ZIP_FILE}"

# %% [markdown]
# # **Bước 2:** Copy dataset xuống Local (để tăng tốc độ xử lý)

# %%
if os.path.exists(DRIVE_PATH):
    print(f"🔄 Đang copy {ZIP_FILE} từ Drive xuống Local...")
    shutil.copy(DRIVE_PATH, LOCAL_PATH)
    print(f"✅ Đã copy xong: {LOCAL_PATH}")
else:
    raise FileNotFoundError(f"❌ Không tìm thấy file: {DRIVE_PATH}. Hãy kiểm tra lại folder data trên Drive.")
# Out:
# 🔄 Đang copy planes_128.zip từ Drive xuống Local...
# ✅ Đã copy xong: /content/planes_128.zip

# %% [markdown]
# # **Bước 3:** Cài đặt môi trường Micromamba

# %%
# %cd /content/drive/MyDrive/HyperNeRFGAN

# Cài Micromamba
# !mkdir -p bin
# !curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj bin/micromamba
# !chmod +x bin/micromamba

# Tạo file environment tối ưu cho Colab
import yaml
env_in = "environment.yaml"
env_out = "environment_colab.yaml"

# Load environment gốc và lọc bỏ imageio-ffmpeg (cài pip sau)
if os.path.exists(env_in):
    y = yaml.safe_load(open(env_in, "r"))
    y["channels"] = ["conda-forge", "defaults"] # Bỏ pytorch channel để cài thủ công
    deps = []
    for d in y.get("dependencies", []):
        if isinstance(d, str) and (d.startswith("imageio-ffmpeg") or d.startswith("pytorch") or d.startswith("torchvision")):
            continue
        deps.append(d)
    y["dependencies"] = deps
    with open(env_out, "w") as f:
        yaml.safe_dump(y, f, sort_keys=False)
else:
    with open(env_out, "w") as f:
        f.write("channels:\n  - conda-forge\ndependencies:\n  - python=3.8\n  - pip\n")

print("✅ Đã tạo file config môi trường:", env_out)

# Tạo môi trường
ENV_PREFIX = "/content/hypernerfgan_env"
# !rm -rf {ENV_PREFIX}
# !./bin/micromamba create -y -p {ENV_PREFIX} -f environment_colab.yaml
# Out:
# /content/drive/MyDrive/HyperNeRFGAN
# bin/micromamba
# ✅ Đã tạo file config môi trường: environment_colab.yaml
# warning  libmamba 'repo.anaconda.com', a commercial channel hosted by Anaconda.com, is used.
#
# warning  libmamba Please make sure you understand Anaconda Terms of Services.
#
# warning  libmamba See: https://legal.anaconda.com/policies/en/
# [+] 0.0s
# [+] 0.1s
# pkgs/main/linux-64..  ⣾
# pkgs/r/noarch (che..  ⣾  [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾
# pkgs/main/linux-64    ⣾
# pkgs/main/noarch      ⣾
# pkgs/r/linux-64       ⣾  pkgs/main/noarch
# pkgs/r/linux-64
# [+] 0.2s
# conda-forge/linux-64   1%
# conda-forge/noarch     3%
# pkgs/main/linux-64    23%
# pkgs/r/noarch         ⣾  [+] 0.3s
# conda-forge/linux-64   7%
# conda-forge/noarch    15%
# pkgs/main/linux-64    53%
# pkgs/r/noarch         25%pkgs/r/noarch
# [+] 0.4s
# conda-forge/linux-64  10%
# conda-forge/noarch    23%
# pkgs/main/linux-64    71%[+] 0.5s
# conda-forge/linux-64  16%
# conda-forge/noarch    34%
# pkgs/main/linux-64    99%pkgs/main/linux-64
# [+] 0.6s
# conda-forge/linux-64  24%
# conda-forge/noarch    51%[+] 0.7s
# conda-forge/linux-64  28%
# conda-forge/noarch    59%[+] 0.8s
# conda-forge/linux-64  32%
# conda-forge/noarch    65%[+] 0.9s
# conda-forge/linux-64  37%
# conda-forge/noarch    77%[+] 1.0s
# conda-forge/linux-64  39%
# conda-forge/noarch    85%[+] 1.1s
# conda-forge/linux-64  44%
# conda-forge/noarch    92%conda-forge/noarch
# [+] 1.2s
# conda-forge/linux-64  48%[+] 1.3s
# conda-forge/linux-64  52%[+] 1.4s
# conda-forge/linux-64  59%[+] 1.5s
# conda-forge/linux-64  67%[+] 1.6s
# conda-forge/linux-64  69%[+] 1.7s
# conda-forge/linux-64  77%[+] 1.8s
# conda-forge/linux-64  83%[+] 1.9s
# conda-forge/linux-64  92%[+] 2.0s
# conda-forge/linux-64  98%conda-forge/linux-64
#
#
# Transaction
#
#   Prefix: /content/hypernerfgan_env
#
#   Updating specs:
#
#    - python=3.8.5
#    - pip=20.3
#    - cudatoolkit=10.2
#    - imageio
#    - protobuf=3.20.1
#    - pip
#
#
#   Package                Version  Build                 Channel          Size
# ───────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex            0.1  conda_forge           conda-forge       3kB
#   + _openmp_mutex            4.5  2_gnu                 conda-forge      24kB
#   + ca-certificates   2025.11.12  hbd8a1cb_0            conda-forge     152kB
#   + cudatoolkit          10.2.89  hdec6ad0_13           conda-forge     368MB
#   + freetype              2.12.1  h267a509_2            conda-forge     635kB
#   + imageio               2.36.0  pyh12aca89_1          conda-forge     292kB
#   + lcms2                   2.16  hb7c19ff_0            conda-forge     245kB
#   + ld_impl_linux-64        2.45  bootstrap_ha15bf96_4  conda-forge     725kB
#   + lerc                   4.0.0  h0aef613_1            conda-forge     264kB
#   + libblas               3.11.0  5_h4a7cf45_openblas   conda-forge      18kB
#   + libcblas              3.11.0  5_h0358290_openblas   conda-forge      18kB
#   + libdeflate              1.20  hd590300_0            conda-forge      72kB
#   + libffi                 3.2.1  he1b5a44_1007         conda-forge      48kB
#   + libgcc                15.2.0  he0feb66_16           conda-forge       1MB
#   + libgcc-ng             15.2.0  h69a702a_16           conda-forge      27kB
#   + libgfortran           15.2.0  h69a702a_16           conda-forge      27kB
#   + libgfortran5          15.2.0  h68bc16d_16           conda-forge       2MB
#   + libgomp               15.2.0  he0feb66_16           conda-forge     603kB
#   + libjpeg-turbo          3.1.2  hb03c661_0            conda-forge     634kB
#   + liblapack             3.11.0  5_h47877c9_openblas   conda-forge      18kB
#   + liblzma                5.8.1  hb9d3cd8_2            conda-forge     113kB
#   + liblzma-devel          5.8.1  hb9d3cd8_2            conda-forge     440kB
#   + libopenblas           0.3.30  pthreads_h94d23a6_4   conda-forge       6MB
#   + libpng                1.6.43  h2797004_0            conda-forge     288kB
#   + libprotobuf           3.20.1  h6239696_4            conda-forge       3MB
#   + libsqlite             3.46.0  hde9e2c9_0            conda-forge     865kB
#   + libstdcxx             15.2.0  h934c35e_16           conda-forge       6MB
#   + libstdcxx-ng          15.2.0  hdf11a46_16           conda-forge      27kB
#   + libtiff                4.6.0  h1dd3fc0_3            conda-forge     283kB
#   + libwebp-base           1.6.0  hd42ef1d_0            conda-forge     429kB
#   + libxcb                  1.15  h0b41bf4_0            conda-forge     384kB
#   + libzlib               1.2.13  h4ab18f5_6            conda-forge      62kB
#   + ncurses                  6.5  h2d0b736_3            conda-forge     892kB
#   + numpy                 1.24.4  py38h59b608b_0        conda-forge       7MB
#   + openjpeg               2.5.2  h488ebb8_0            conda-forge     342kB
#   + openssl               1.1.1w  hd590300_0            conda-forge       2MB
#   + pillow                10.3.0  py38h9e66945_0        conda-forge      42MB
#   + pip                   20.3.4  pyhd8ed1ab_0          conda-forge       1MB
#   + protobuf              3.20.1  py38hfa26641_0        conda-forge     340kB
#   + pthread-stubs            0.4  hb9d3cd8_1002         conda-forge       8kB
#   + python                 3.8.5  h1103e12_9_cpython    conda-forge      23MB
#   + python_abi               3.8  8_cp38                conda-forge       7kB
#   + readline                 8.3  h853b02a_0            conda-forge     345kB
#   + setuptools            75.3.0  pyhd8ed1ab_0          conda-forge     780kB
#   + six                   1.16.0  pyh6c4a22f_0          conda-forge      14kB
#   + sqlite                3.46.0  h6d4b2fc_0            conda-forge     860kB
#   + tk                    8.6.13  noxft_h4845f30_101    conda-forge       3MB
#   + wheel                 0.45.1  pyhd8ed1ab_0          conda-forge      63kB
#   + xorg-libxau           1.0.12  hb03c661_1            conda-forge      15kB
#   + xorg-libxdmcp          1.1.5  hb03c661_1            conda-forge      21kB
#   + xz                     5.8.1  hbcc6ac9_2            conda-forge      24kB
#   + xz-gpl-tools           5.8.1  hbcc6ac9_2            conda-forge      34kB
#   + xz-tools               5.8.1  hb9d3cd8_2            conda-forge      96kB
#   + zlib                  1.2.13  h4ab18f5_6            conda-forge      93kB
#   + zstd                   1.5.6  ha6fb4c9_0            conda-forge     555kB
#
#   Summary:
#
#   Install: 55 packages
#
#   Total download: 476MB
#
# ───────────────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# [+] 0.0s
# Downloading        5%
# Extracting         0%[+] 0.1s
# Downloading  (5)   0%
# Extracting         0%libopenblas                                          5.9MB @  27.7MB/s  0.1s
# numpy                                                6.7MB @  20.4MB/s  0.1s
# [+] 0.2s
# Downloading  (5)   6%
# Extracting         0%[+] 0.3s
# Downloading  (5)  10%
# Extracting   (2)  ⣾  tk                                                   3.3MB @  11.4MB/s  0.2s
# [+] 0.4s
# Downloading  (5)  14%
# Extracting   (3)  ⣾  libstdcxx                                            5.9MB @  24.3MB/s  0.2s
# libprotobuf                                          2.7MB @  ??.?MB/s  0.1s
# [+] 0.5s
# Downloading  (5)  18%
# Extracting   (4)  ⣾  python                                              23.0MB @  45.0MB/s  0.5s
# libgfortran5                                         2.5MB @   9.7MB/s  0.1s
# libgcc                                               1.0MB @   9.4MB/s  0.1s
# [+] 0.6s
# Downloading  (5)  21%
# Extracting   (6)  ⣾  pip                                                  1.1MB @   3.0MB/s  0.1s
# openssl                                              2.0MB @   8.2MB/s  0.2s
# ncurses                                            891.6kB @  11.3MB/s  0.1s
# libsqlite                                          865.3kB @   6.5MB/s  0.1s
# [+] 0.7s
# Downloading  (5)  23%
# Extracting  (10)  ⣾  sqlite                                             860.4kB @  ??.?MB/s  0.1s
# setuptools                                         779.6kB @   3.0MB/s  0.1s
# ld_impl_linux-64                                   724.8kB @   3.2MB/s  0.1s
# [+] 0.8s
# Downloading  (5)  25%
# Extracting  (14)  ⣾  libgomp                                            603.3kB @   5.8MB/s  0.1s
# libjpeg-turbo                                      633.7kB @   3.3MB/s  0.1s
# [+] 0.9s
# Downloading  (5)  26%
# Extracting  (15)  ⣾  liblzma-devel                                      439.9kB @   2.6MB/s  0.1s
# zstd                                               554.8kB @   2.4MB/s  0.1s
# freetype                                           635.0kB @  ??.?MB/s  0.2s
# [+] 1.0s
# Downloading  (5)  29%
# Extracting  (19)  ⣾  libwebp-base                                       429.0kB @   2.7MB/s  0.1s
# libxcb                                             384.2kB @   2.8MB/s  0.1s
# readline                                           345.1kB @  ??.?MB/s  0.1s
# protobuf                                           339.7kB @   6.8MB/s  0.1s
# openjpeg                                           341.6kB @   3.0MB/s  0.1s
# [+] 1.1s
# Downloading  (4)  30%
# Extracting  (22)  ⣾  imageio                                            292.1kB @   2.1MB/s  0.1s
# libpng                                             288.2kB @  ??.?MB/s  0.0s
# lcms2                                              245.2kB @  ??.?MB/s  0.0s
# libtiff                                            282.7kB @  ??.?MB/s  0.1s
# lerc                                               264.2kB @  ??.?MB/s  0.1s
# [+] 1.2s
# Downloading  (5)  33%
# Extracting  (27)  ⣾  ca-certificates                                    152.4kB @  ??.?MB/s  0.0s
# liblzma                                            112.9kB @  ??.?MB/s  0.0s
# pillow                                              42.3MB @  32.5MB/s  1.2s
# xz-tools                                            96.4kB @   1.8MB/s  0.1s
# zlib                                                92.9kB @  ??.?MB/s  0.0s
# libdeflate                                          71.5kB @  ??.?MB/s  0.0s
# wheel                                               63.0kB @   1.2MB/s  0.1s
# libzlib                                             61.6kB @  ??.?MB/s  0.1s
# [+] 1.3s
# Downloading  (5)  36%
# Extracting  (33)  ⣾  libffi                                              48.0kB @  ??.?MB/s  0.1s
# xz-gpl-tools                                        33.9kB @ 442.7kB/s  0.1s
# libstdcxx-ng                                        27.3kB @ 379.4kB/s  0.1s
# libgcc-ng                                           27.3kB @ 378.4kB/s  0.1s
# libgfortran                                         27.2kB @ 499.9kB/s  0.1s
# [+] 1.4s
# Downloading  (5)  38%
# Extracting  (39)  ⣾  xz                                                  24.0kB @  ??.?MB/s  0.0s
# libblas                                             18.2kB @  ??.?MB/s  0.0s
# _openmp_mutex                                       23.6kB @ 406.2kB/s  0.1s
# xorg-libxdmcp                                       20.6kB @ 353.7kB/s  0.1s
# liblapack                                           18.2kB @  ??.?MB/s  0.0s
# libcblas                                            18.2kB @  ??.?MB/s  0.0s
# xorg-libxau                                         15.3kB @  ??.?MB/s  0.0s
# [+] 1.5s
# Downloading  (5)  39%
# Extracting  (46)  ⣾  six                                                 14.3kB @  ??.?MB/s  0.1s
# pthread-stubs                                        8.3kB @  ??.?MB/s  0.0s
# python_abi                                           7.0kB @  ??.?MB/s  0.1s
# _libgcc_mutex                                        2.6kB @  ??.?MB/s  0.0s
# [+] 1.6s
# Downloading  (1)  41%
# Extracting  (49)  ⣾  [+] 1.7s
# Downloading  (1)  43%
# Extracting  (48)  ⣾  [+] 1.8s
# Downloading  (1)  46%
# Extracting  (46)  ⣾  [+] 1.9s
# Downloading  (1)  48%
# Extracting  (46)  ⣾  [+] 2.0s
# Downloading  (1)  52%
# Extracting  (45)  ⣾  [+] 2.1s
# Downloading  (1)  54%
# Extracting  (45)  ⣾  [+] 2.2s
# Downloading  (1)  57%
# Extracting  (44)  ⣾  [+] 2.3s
# Downloading  (1)  59%
# Extracting  (43)  ⣾  [+] 2.4s
# Downloading  (1)  60%
# Extracting  (42)  ⣾  [+] 2.5s
# Downloading  (1)  63%
# Extracting  (41)  ⣾  [+] 2.6s
# Downloading  (1)  66%
# Extracting  (39)  ⣾  [+] 2.7s
# Downloading  (1)  70%
# Extracting  (38)  ⣾  [+] 2.8s
# Downloading  (1)  72%
# Extracting  (37)  ⣾  [+] 2.9s
# Downloading  (1)  73%
# Extracting  (35)  ⣾  [+] 3.0s
# Downloading  (1)  77%
# Extracting  (34)  ⣾  [+] 3.1s
# Downloading  (1)  81%
# Extracting  (33)  ⣾  [+] 3.2s
# Downloading  (1)  85%
# Extracting  (33)  ⣾  [+] 3.3s
# Downloading  (1)  89%
# Extracting  (33)  ⣾  [+] 3.4s
# Downloading  (1)  93%
# Extracting  (31)  ⣾  [+] 3.5s
# Downloading  (1)  95%
# Extracting  (29)  ⣾  [+] 3.6s
# Downloading  (1)  96%
# Extracting  (29)  ⣾  [+] 3.7s
# Downloading  (1)  97%
# Extracting  (28)  ⣾  cudatoolkit                                        368.4MB @  87.6MB/s  4.1s
# [+] 4.2s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 4.3s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 4.4s
# Downloading      100%
# Extracting  (26)  ⣾  [+] 4.5s
# Downloading      100%
# Extracting  (26)  ⣾  [+] 4.6s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 4.7s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 4.8s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 4.9s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 5.0s
# Downloading      100%
# Extracting  (24)  ⣾  [+] 5.1s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 5.2s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 5.3s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 5.4s
# Downloading      100%
# Extracting  (20)  ⣾  [+] 5.5s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 5.6s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 5.7s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 5.8s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 5.9s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 6.0s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 6.1s
# Downloading      100%
# Extracting  (14)  ⣾  [+] 6.2s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 6.3s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 6.4s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 6.5s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 6.6s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 6.7s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 6.8s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 6.9s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.0s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.2s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 7.3s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 7.4s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 7.5s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.6s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.7s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.8s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 7.9s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 8.0s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 8.1s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 8.2s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 8.3s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 8.4s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 8.5s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 8.6s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 8.7s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 8.8s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 8.9s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.0s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.1s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.2s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.3s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.4s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.5s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.6s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.7s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.8s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 9.9s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 10.0s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 10.1s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 10.2s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 10.3s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 10.4s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 10.5s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 10.6s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 10.7s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 10.8s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 10.9s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 11.0s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 11.1s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 11.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 11.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 11.4s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.5s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.6s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.7s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.8s
# Downloading      100%
# Extracting   (1)  ⣾  [+] 11.9s
# Downloading      100%
# Extracting   (1)  ⣾  Linking python_abi-3.8-8_cp38
# Linking ca-certificates-2025.11.12-hbd8a1cb_0
# Linking libgomp-15.2.0-he0feb66_16
# Linking _libgcc_mutex-0.1-conda_forge
# Linking ld_impl_linux-64-2.45-bootstrap_ha15bf96_4
# Linking _openmp_mutex-4.5-2_gnu
# Linking libgcc-15.2.0-he0feb66_16
# Linking libgfortran5-15.2.0-h68bc16d_16
# Linking ncurses-6.5-h2d0b736_3
# Linking libjpeg-turbo-3.1.2-hb03c661_0
# Linking xorg-libxdmcp-1.1.5-hb03c661_1
# Linking xorg-libxau-1.0.12-hb03c661_1
# Linking pthread-stubs-0.4-hb9d3cd8_1002
# Linking libwebp-base-1.6.0-hd42ef1d_0
# Linking libstdcxx-15.2.0-h934c35e_16
# Linking libgcc-ng-15.2.0-h69a702a_16
# Linking liblzma-5.8.1-hb9d3cd8_2
# Linking libgfortran-15.2.0-h69a702a_16
# Linking readline-8.3-h853b02a_0
# Linking lerc-4.0.0-h0aef613_1
# Linking libstdcxx-ng-15.2.0-hdf11a46_16
# Linking openssl-1.1.1w-hd590300_0
# Linking libxcb-1.15-h0b41bf4_0
# Linking libdeflate-1.20-hd590300_0
# Linking libzlib-1.2.13-h4ab18f5_6
# Linking xz-tools-5.8.1-hb9d3cd8_2
# Linking xz-gpl-tools-5.8.1-hbcc6ac9_2
# Linking liblzma-devel-5.8.1-hb9d3cd8_2
# Linking libopenblas-0.3.30-pthreads_h94d23a6_4
# Linking libffi-3.2.1-he1b5a44_1007
# Linking cudatoolkit-10.2.89-hdec6ad0_13
# By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# Linking libsqlite-3.46.0-hde9e2c9_0
# Linking zstd-1.5.6-ha6fb4c9_0
# Linking libpng-1.6.43-h2797004_0
# Linking tk-8.6.13-noxft_h4845f30_101
# Linking libprotobuf-3.20.1-h6239696_4
# Linking zlib-1.2.13-h4ab18f5_6
# Linking xz-5.8.1-hbcc6ac9_2
# Linking libblas-3.11.0-5_h4a7cf45_openblas
# Linking sqlite-3.46.0-h6d4b2fc_0
# Linking freetype-2.12.1-h267a509_2
# Linking libtiff-4.6.0-h1dd3fc0_3
# Linking libcblas-3.11.0-5_h0358290_openblas
# Linking liblapack-3.11.0-5_h47877c9_openblas
# Linking python-3.8.5-h1103e12_9_cpython
# Linking lcms2-2.16-hb7c19ff_0
# Linking openjpeg-2.5.2-h488ebb8_0
# Linking wheel-0.45.1-pyhd8ed1ab_0
# Linking setuptools-75.3.0-pyhd8ed1ab_0
# Linking pip-20.3.4-pyhd8ed1ab_0
# Linking six-1.16.0-pyh6c4a22f_0
# Linking pillow-10.3.0-py38h9e66945_0
# Linking numpy-1.24.4-py38h59b608b_0
# Linking protobuf-3.20.1-py38hfa26641_0
# Linking imageio-2.36.0-pyh12aca89_1
#
# Transaction finished
#
#
# To activate this environment, use:
#
#     micromamba activate /content/hypernerfgan_env
#
# Or to execute a single command in this environment, use:
#
#     micromamba run -p /content/hypernerfgan_env mycommand
#
# warning  libmamba You are using 'pip' as an additional package manager.
#     Be aware that packages installed with 'pip' are managed independently from 'conda-forge' channel.
#
# Installing pip packages: hydra-core==1.0.6, click==7.1.2, scipy==1.6.1, ninja==1.10.0, tensorboard==2.4.1, tqdm==4.59.0, gitpython, gpustat, opencv-python, -e .
#      |████████████████████████████████| 123 kB 9.7 MB/s
#      |████████████████████████████████| 82 kB 1.1 MB/s
#      |████████████████████████████████| 27.3 MB 1.2 MB/s
#      |████████████████████████████████| 102 kB 78.2 MB/s
#      |████████████████████████████████| 10.6 MB 69.2 MB/s
#      |████████████████████████████████| 74 kB 3.5 MB/s
#      |████████████████████████████████| 208 kB 74.9 MB/s
#      |████████████████████████████████| 98 kB 10.0 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 67.0 MB 8.0 kB/s
#      |████████████████████████████████| 112 kB 80.8 MB/s
#      |████████████████████████████████| 106 kB 74.9 MB/s
#      |████████████████████████████████| 6.0 MB 60.5 MB/s
#      |████████████████████████████████| 135 kB 76.8 MB/s
#      |████████████████████████████████| 781 kB 58.1 MB/s
#      |████████████████████████████████| 227 kB 69.0 MB/s
#      |████████████████████████████████| 64 kB 4.3 MB/s
#      |████████████████████████████████| 152 kB 72.7 MB/s
#      |████████████████████████████████| 181 kB 75.0 MB/s
#      |████████████████████████████████| 806 kB 55.5 MB/s
#      |████████████████████████████████| 83 kB 2.0 MB/s
#      |████████████████████████████████| 159 kB 68.2 MB/s
#      |████████████████████████████████| 126 kB 28.5 MB/s
#      |████████████████████████████████| 147 kB 80.8 MB/s
#      |████████████████████████████████| 71 kB 12.3 MB/s
#      |████████████████████████████████| 160 kB 56.2 MB/s
#      |████████████████████████████████| 62 kB 1.8 MB/s
#      |████████████████████████████████| 263 kB 79.5 MB/s
#      |████████████████████████████████| 50 kB 8.9 MB/s
#      |████████████████████████████████| 95 kB 5.6 MB/s
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for gpustat (PEP 517) ... done

# %% [markdown]
# # **Bước 4:** Cài đặt Pytorch và Dependencies

# %%
print("⬇️ Đang cài đặt PyTorch và thư viện...")

# 1. Cài PyTorch chuẩn (CUDA 11.3)
# !./bin/micromamba run -p {ENV_PREFIX} \
  pip install torch==1.10.0+cu113 torchvision==0.11.0+cu113 \
  --extra-index-url https://download.pytorch.org/whl/cu113

# 2. Cài cố định phiên bản Pip và Setuptools cũ (Quan trọng)
# (Pip 23.3.1 để fix lỗi omegaconf, Setuptools<59.6 để fix lỗi distutils)
# !./bin/micromamba run -p {ENV_PREFIX} pip install "pip==23.3.1" "setuptools<59.6.0" wheel

# 3. Cài repo ở chế độ editable
# !./bin/micromamba run -p {ENV_PREFIX} pip install -e .

# 4. Cài Hydra & Dependencies
# !./bin/micromamba run -p {ENV_PREFIX} \
  pip install hydra-core==1.0.6 omegaconf==2.0.6 antlr4-python3-runtime==4.8

# 5. Cài các util khác
# !./bin/micromamba run -p {ENV_PREFIX} \
  pip install imageio-ffmpeg opencv-python tensorboard tqdm gpustat gitpython ninja

print("✅ Đã cài đặt xong môi trường (Dependencies OK).")


# # 1. Cài PyTorch chuẩn (CUDA 11.3)
# !./bin/micromamba run -p {ENV_PREFIX} \
#   pip install torch==1.10.0+cu113 torchvision==0.11.0+cu113 \
#   --extra-index-url https://download.pytorch.org/whl/cu113

# # 2. QUAN TRỌNG: Cài cố định phiên bản Pip và Setuptools cũ
# !./bin/micromamba run -p {ENV_PREFIX} pip install "pip==23.3.1" "setuptools<59.6.0" wheel

# # 3. Cài repo ở chế độ editable
# !./bin/micromamba run -p {ENV_PREFIX} pip install -e .

# # 4. Cài Hydra & Dependencies
# !./bin/micromamba run -p {ENV_PREFIX} \
#   pip install hydra-core==1.0.6 omegaconf==2.0.6 antlr4-python3-runtime==4.8

# # 5. Cài các util khác VÀ CHỐT NUMPY 1.23.5
# !./bin/micromamba run -p {ENV_PREFIX} \
#   pip install imageio-ffmpeg opencv-python tensorboard tqdm gpustat gitpython ninja "numpy==1.23.5"

# print("✅ Đã cài đặt xong môi trường (Dependencies OK).")
# Out:
# ⬇️ Đang cài đặt PyTorch và thư viện...
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Collecting torch==1.10.0+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torch-1.10.0%2Bcu113-cp38-cp38-linux_x86_64.whl (1821.4 MB)
#      |████████████████████████████████| 1821.4 MB 1.1 kB/s
# Collecting torchvision==0.11.0+cu113
#   Downloading https://download.pytorch.org/whl/cu113/torchvision-0.11.0%2Bcu113-cp38-cp38-linux_x86_64.whl (21.8 MB)
#      |████████████████████████████████| 21.8 MB 1.2 MB/s
# Requirement already satisfied: typing-extensions in /content/hypernerfgan_env/lib/python3.8/site-packages (from torch==1.10.0+cu113) (4.13.2)
# Requirement already satisfied: numpy in /content/hypernerfgan_env/lib/python3.8/site-packages (from torchvision==0.11.0+cu113) (1.24.4)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /content/hypernerfgan_env/lib/python3.8/site-packages (from torchvision==0.11.0+cu113) (10.3.0)
# Installing collected packages: torch, torchvision
# Successfully installed torch-1.10.0+cu113 torchvision-0.11.0+cu113
# Collecting pip==23.3.1
#   Downloading pip-23.3.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 10.3 MB/s
# Collecting setuptools<59.6.0
#   Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#      |████████████████████████████████| 952 kB 63.9 MB/s
# Requirement already satisfied: wheel in /content/hypernerfgan_env/lib/python3.8/site-packages (0.45.1)
# Installing collected packages: setuptools, pip
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.3.0
#     Uninstalling setuptools-75.3.0:
#       Successfully uninstalled setuptools-75.3.0
#   Attempting uninstall: pip
#     Found existing installation: pip 20.3.4
#     Uninstalling pip-20.3.4:
#       Successfully uninstalled pip-20.3.4
# Successfully installed pip-23.3.1 setuptools-59.5.0
# Obtaining file:///content/drive/MyDrive/HyperNeRFGAN
#   Preparing metadata (setup.py) ... done
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: inr-gan
#   Attempting uninstall: inr-gan
#     Found existing installation: inr_gan 0.0.1
#     Uninstalling inr_gan-0.0.1:
#       Successfully uninstalled inr_gan-0.0.1
#   Running setup.py develop for inr-gan
# Successfully installed inr-gan-0.0.1
# Requirement already satisfied: hydra-core==1.0.6 in /content/hypernerfgan_env/lib/python3.8/site-packages (1.0.6)
# Requirement already satisfied: omegaconf==2.0.6 in /content/hypernerfgan_env/lib/python3.8/site-packages (2.0.6)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /content/hypernerfgan_env/lib/python3.8/site-packages (4.8)
# Requirement already satisfied: importlib-resources in /content/hypernerfgan_env/lib/python3.8/site-packages (from hydra-core==1.0.6) (6.4.5)
# Requirement already satisfied: PyYAML>=5.1.* in /content/hypernerfgan_env/lib/python3.8/site-packages (from omegaconf==2.0.6) (6.0.3)
# Requirement already satisfied: typing-extensions in /content/hypernerfgan_env/lib/python3.8/site-packages (from omegaconf==2.0.6) (4.13.2)
# Requirement already satisfied: zipp>=3.1.0 in /content/hypernerfgan_env/lib/python3.8/site-packages (from importlib-resources->hydra-core==1.0.6) (3.20.2)
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Collecting imageio-ffmpeg
#   Downloading imageio_ffmpeg-0.5.1-py3-none-manylinux2010_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: opencv-python in /content/hypernerfgan_env/lib/python3.8/site-packages (4.12.0.88)
# Requirement already satisfied: tensorboard in /content/hypernerfgan_env/lib/python3.8/site-packages (2.4.1)
# Requirement already satisfied: tqdm in /content/hypernerfgan_env/lib/python3.8/site-packages (4.59.0)
# Requirement already satisfied: gpustat in /content/hypernerfgan_env/lib/python3.8/site-packages (1.1.1)
# Requirement already satisfied: gitpython in /content/hypernerfgan_env/lib/python3.8/site-packages (3.1.45)
# Requirement already satisfied: ninja in /content/hypernerfgan_env/lib/python3.8/site-packages (1.10.0)
# Requirement already satisfied: setuptools in /content/hypernerfgan_env/lib/python3.8/site-packages (from imageio-ffmpeg) (59.5.0)
# Requirement already satisfied: numpy<2.0 in /content/hypernerfgan_env/lib/python3.8/site-packages (from opencv-python) (1.24.4)
# Requirement already satisfied: absl-py>=0.4 in /content/hypernerfgan_env/lib/python3.8/site-packages (from tensorboard) (2.3.1)
# Requirement already satisfied: grpcio>=1.24.3 in /content/hypernerfgan_env/lib/python3.8/site-packages (from tensorboard) (1.70.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /content/hypernerfgan_env/lib/python3.8/site-packages (from tensorboard) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /content/hypernerfgan_env/lib/python3.8/site-packages (from tensorboard) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /content/hypernerfgan_env/lib/python3.8/site-packages (from tensorboard) (3.7)
# Requirement already satisfied: protobuf>=3.6.0 in /content/hypernerfgan_env/lib/python3.8/site-packages (from tensorboard) (3.20.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /content/hypernerfgan_env/lib/python3.8/site-packages (from tensorboard) (2.32.4)
# Requirement already satisfied: six>=1.10.0 in /content/hypernerfgan_env/lib/python3.8/site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /content/hypernerfgan_env/lib/python3.8/site-packages (from tensorboard) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /content/hypernerfgan_env/lib/python3.8/site-packages (from tensorboard) (3.0.6)
# Requirement already satisfied: wheel>=0.26 in /content/hypernerfgan_env/lib/python3.8/site-packages (from tensorboard) (0.45.1)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in /content/hypernerfgan_env/lib/python3.8/site-packages (from gpustat) (13.590.44)
# Requirement already satisfied: psutil>=5.6.0 in /content/hypernerfgan_env/lib/python3.8/site-packages (from gpustat) (7.1.3)
# Requirement already satisfied: blessed>=1.17.1 in /content/hypernerfgan_env/lib/python3.8/site-packages (from gpustat) (1.25.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /content/hypernerfgan_env/lib/python3.8/site-packages (from gitpython) (4.0.12)
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /content/hypernerfgan_env/lib/python3.8/site-packages (from gitpython) (4.13.2)
# Requirement already satisfied: wcwidth>=0.1.4 in /content/hypernerfgan_env/lib/python3.8/site-packages (from blessed>=1.17.1->gpustat) (0.2.14)
# Requirement already satisfied: smmap<6,>=3.0.1 in /content/hypernerfgan_env/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython) (5.0.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /content/hypernerfgan_env/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /content/hypernerfgan_env/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /content/hypernerfgan_env/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /content/hypernerfgan_env/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /content/hypernerfgan_env/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard) (8.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /content/hypernerfgan_env/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /content/hypernerfgan_env/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /content/hypernerfgan_env/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /content/hypernerfgan_env/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard) (2025.11.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /content/hypernerfgan_env/lib/python3.8/site-packages (from werkzeug>=0.11.15->tensorboard) (2.1.5)
# Requirement already satisfied: zipp>=3.20 in /content/hypernerfgan_env/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard) (3.20.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /content/hypernerfgan_env/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /content/hypernerfgan_env/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.3.1)
# Downloading imageio_ffmpeg-0.5.1-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 84.9 MB/s eta 0:00:00
# DEPRECATION: omegaconf 2.0.6 has a non-standard dependency specifier PyYAML>=5.1.*. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of omegaconf or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Installing collected packages: imageio-ffmpeg
# Successfully installed imageio-ffmpeg-0.5.1
# ✅ Đã cài đặt xong môi trường (Dependencies OK).

# %% [markdown]
# # **Bước 5:** Patch config cho `main.yml`

# %%
main_cfg = "configs/main.yml"
import re
if os.path.exists(main_cfg):
    txt = open(main_cfg, "r").read()
    txt = re.sub(r"^num_gpus:\s*\d+.*$", "num_gpus: 1", txt, flags=re.M)
    open(main_cfg, "w").write(txt)
    print("✅ Đã patch configs/main.yml")
# Out:
# ✅ Đã patch configs/main.yml

# %% [markdown]
# # **Bước 6:** Memory fix ứng với từng file `<dataset>.yml`

# %%
# Fix OOM cho T4 GPU
planes_cfg = "configs/nerf-gan-planes.yml"
if os.path.exists(planes_cfg):
    c = open(planes_cfg,"r").read()
    # Giảm từ 64 xuống 32 hoặc 48 để tránh tràn VRAM
    c = c.replace("patch_size: 64", "patch_size: 32")
    c = c.replace("n_samples: 64", "n_samples: 32")
    open(planes_cfg,"w").write(c)
    print(f"✅ Đã giảm cấu hình memory trong {planes_cfg}")
# Out:
# ✅ Đã giảm cấu hình memory trong configs/nerf-gan-planes.yml

# %% [markdown]
# # **Bước 7:** Xử lý đồng loạt cái file `*.yml` chuẩn bị cho training

# %%
import glob
import os
import re

CONFIG_DIR = "configs"
config_dir = "/content/drive/MyDrive/HyperNeRFGAN/configs"

# Lấy tất cả file trong folder configs
files = os.listdir(config_dir)

for f in files:
    full_path = os.path.join(config_dir, f)

    # Nếu là .yaml -> copy thêm bản .yml
    if f.endswith(".yaml"):
        target = full_path.replace(".yaml", ".yml")
        if not os.path.exists(target):
            shutil.copy(full_path, target)
            print(f"   Created clone: {os.path.basename(target)}")

    # Nếu là .yml -> copy thêm bản .yaml
    elif f.endswith(".yml"):
        target = full_path.replace(".yml", ".yaml")
        if not os.path.exists(target):
            shutil.copy(full_path, target)
            print(f"   Created clone: {os.path.basename(target)}")

print("✅ Configs đã sẵn sàng (Dual extension).")

# 2. Patch file main.yaml (Set 1 GPU)
main_cfg = os.path.join(CONFIG_DIR, "main.yaml")
if os.path.exists(main_cfg):
    txt = open(main_cfg, "r").read()
    # Force 1 GPU
    txt = re.sub(r"^num_gpus:\s*\d+.*$", "num_gpus: 1", txt, flags=re.M)
    # Sửa tham chiếu đến file config con (cũng phải đổi thành yaml nếu có hardcode)
    open(main_cfg, "w").write(txt)
    print("✅ Đã patch main.yaml (num_gpus=1)")

# 3. Patch file dataset config (Fix OOM cho T4 GPU)
# Tự động tìm file config tương ứng với DATASET_NAME
target_cfg_name = f"nerf-gan-{DATASET_NAME.split('_')[0]}" # Vd: planes_128 -> nerf-gan-planes
dataset_cfg = os.path.join(CONFIG_DIR, f"{target_cfg_name}.yaml")

if os.path.exists(dataset_cfg):
    c = open(dataset_cfg, "r").read()
    # Giảm thông số để vừa với 16GB VRAM của T4
    c = c.replace("patch_size: 64", "patch_size: 32")
    c = c.replace("n_samples: 64", "n_samples: 32") # Giảm bớt số mẫu trên tia
    open(dataset_cfg, "w").write(c)
    print(f"✅ Đã tối ưu bộ nhớ trong {dataset_cfg}")
else:
    print(f"⚠️ Cảnh báo: Không tìm thấy config {dataset_cfg}. Có thể tên dataset khác với quy tắc đặt tên config.")
# Out:
# ✅ Configs đã sẵn sàng (Dual extension).
# ✅ Đã patch main.yaml (num_gpus=1)
# ✅ Đã tối ưu bộ nhớ trong configs/nerf-gan-planes.yaml

# %% [markdown]
# # **Bước 8:** Chạy training

# %%
print("🚀 Bắt đầu Training...")

# !./bin/micromamba run -p {ENV_PREFIX} \
  python src/infra/launch_local.py hydra.run.dir=. \
  +experiment_name=planes_128_t4_run1 \
  +dataset.name=planes_128 \
  +dataset.root_path={LOCAL_PATH} \
  num_gpus=1 \
  +D_kwargs.patch_size=32 \
  +G_kwargs.synthesis_kwargs.patch_size=32 \
  +G_kwargs.cfg.patch_size=32
# Out:
# 🚀 Bắt đầu Training...
# <=== CONFIG ===>
# env:
#   python_bin: python
#   base_project_dir: ${hydra:runtime.cwd}
#   before_train_commands: []
#   torch_extensions_dir: /tmp/torch_extensions
#   datasets_dir: data
#   objects_to_copy:
#   - ${env.base_project_dir}/src
#   - ${env.base_project_dir}/configs
#   symlinks_to_create:
#   - ${env.base_project_dir}/data
# num_gpus: 1
# dataset:
#   source_path: ${env.datasets_dir}/${dataset.name}.zip
#   target_path: data/${dataset.name}.zip
#   name: planes_128
#   root_path: /content/planes_128.zip
# print_only: false
# project_release_dir: /content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None
# train_args:
#   outdir: ${project_release_dir}
#   data: ${dataset.target_path}
#   gpus: ${num_gpus}
#   metrics: fid1k_full
#   cfg: nerf
#   generate_video: true
#   video_front_view: true
#   snap: 50
#   aug: fixed
#   augpipe: crop
#   p: 0.5
#   mirror: 1
#   hydra_cfg_name: nerf-gan-chairs.yml
# train_args_str: --outdir=/content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None
#   --data=data/planes_128.zip --gpus=1 --metrics=fid1k_full --cfg=nerf --generate_video=True
#   --video_front_view=True --snap=50 --aug=fixed --augpipe=crop --p=0.5 --mirror=1
#   --hydra_cfg_name=nerf-gan-chairs.yml
# experiment_name: planes_128_t4_run1
# D_kwargs:
#   patch_size: 32
# G_kwargs:
#   synthesis_kwargs:
#     patch_size: 32
#   cfg:
#     patch_size: 32
#
# <=== TRAINING COMMAND ===>
#
#  TORCH_EXTENSIONS_DIR=/tmp/torch_extensions python src/train.py --outdir=/content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None --data=data/planes_128.zip --gpus=1 --metrics=fid1k_full --cfg=nerf --generate_video=True --video_front_view=True --snap=50 --aug=fixed --augpipe=crop --p=0.5 --mirror=1 --hydra_cfg_name=nerf-gan-chairs.yml
# Creating a symlink to /content/drive/MyDrive/HyperNeRFGAN/data, so try not to delete it occasionally!
# Created a project dir: /content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None
# src/train.py:40: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "bool"):
# src/train.py:42: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
#
# Training options:
# {
#   "num_gpus": 1,
#   "image_snapshot_ticks": 50,
#   "network_snapshot_ticks": 50,
#   "generate_video": true,
#   "video_front_view": true,
#   "metrics": [
#     "fid1k_full"
#   ],
#   "random_seed": 0,
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "data/planes_128.zip",
#     "use_labels": false,
#     "max_size": 202200,
#     "xflip": true,
#     "resolution": 128
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "num_workers": 3,
#     "prefetch_factor": 2
#   },
#   "D_kwargs": {
#     "class_name": "training.networks.Discriminator",
#     "block_kwargs": {},
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "patch_size": 32,
#     "channel_max": 512,
#     "channel_base": 32768,
#     "num_fp16_res": 4,
#     "conv_clamp": 256
#   },
#   "G_kwargs": {
#     "class_name": "training.networks.NeRFGenerator",
#     "z_dim": 128,
#     "w_dim": 128,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "synthesis_kwargs": {
#       "width": 128,
#       "num_layers": 8,
#       "perturb": 1.0,
#       "raw_noise_std": 1.0,
#       "n_samples": 32,
#       "n_importance": 0,
#       "white_bkgd": true,
#       "patch_size": 32,
#       "theta_low": -180,
#       "theta_high": 180,
#       "phi_low": -90,
#       "phi_high": 0,
#       "render_size": 2.0,
#       "shift": -0.3,
#       "use_normal": false,
#       "theta_std": 1.0
#     },
#     "cfg": {
#       "width": 128,
#       "num_layers": 8,
#       "perturb": 1.0,
#       "raw_noise_std": 1.0,
#       "n_samples": 32,
#       "n_importance": 0,
#       "white_bkgd": true,
#       "patch_size": 32,
#       "phi_low": -90,
#       "phi_high": 0,
#       "theta_low": -180,
#       "theta_high": 180,
#       "render_size": 2.0,
#       "shift": -0.3,
#       "fmm": {
#         "enabled": true,
#         "rank": 10,
#         "activation": "demod"
#       }
#     }
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "lr": 0.0025,
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "lr": 0.0025,
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
#     "r1_gamma": 0.1,
#     "style_mixing_prob": 0.0,
#     "pl_weight": 0
#   },
#   "total_kimg": 204,
#   "batch_size": 4,
#   "batch_gpu": 4,
#   "ema_kimg": 20,
#   "ema_rampup": 0.05,
#   "augment_p": 0.5,
#   "augment_kwargs": {
#     "class_name": "training.augment.AugmentPipe",
#     "crop": true,
#     "xflip": 1
#   },
#   "run_dir": "/content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None/00000-planes_128-mirror-nerf-r1_gamma0.1-fixed-p0.5-crop"
# }
#
# Output directory:   /content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None/00000-planes_128-mirror-nerf-r1_gamma0.1-fixed-p0.5-crop
# Training data:      data/planes_128.zip
# Training duration:  204 kimg
# Number of GPUs:     1
# Number of images:   202200
# Image resolution:   128
# Conditional model:  False
# Dataset x-flips:    True
#
# Creating output directory...
# Launching processes...
# Loading training set...
# /content/hypernerfgan_env/lib/python3.8/site-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None/src/train.py:40: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "bool"):
# /content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None/src/train.py:42: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# /content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None/src/train.py:40: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "bool"):
# /content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None/src/train.py:42: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# /content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None/src/train.py:40: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "bool"):
# /content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None/src/train.py:42: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
#
# Num images:  404400
# Image shape: [3, 128, 128]
# Label shape: [0]
#
# Constructing networks...
# Setting up PyTorch plugin "bias_act_plugin"... Done.
# /content/hypernerfgan_env/lib/python3.8/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#
# NeRFGenerator                   Parameters  Buffers  Input Shape              Output shape      Datatype
# ---                             ---         ---      ---                      ---               ---
# mapping.fc0                     16512       -        [4, 128]                 [4, 128]          float32
# mapping.fc1                     16512       -        [4, 128]                 [4, 128]          float32
# synthesis.pts_linears.0.affine  246390      -        [1, 128]                 [1, 1910]         float32
# synthesis.pts_linears.0         8192        -        [32768, 63] + [1, 128]   [32768, 128]      float32
# synthesis.pts_linears.1.affine  330240      -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.1         16512       -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.2.affine  330240      -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.2         16512       -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.3.affine  330240      -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.3         16512       -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.4.affine  330240      -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.4         16512       -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.5.affine  411510      -        [1, 128]                 [1, 3190]         float32
# synthesis.pts_linears.5         24576       -        [32768, 191] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.6.affine  330240      -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.6         16512       -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.7.affine  330240      -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.7         16512       -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.output_linear.affine  170280      -        [1, 128]                 [1, 1320]         float32
# synthesis.output_linear         516         -        [32768, 128] + [1, 128]  [32768, 4]        float32
# synthesis.pts_linears.0.affine  -           -        [1, 128]                 [1, 1910]         float32
# synthesis.pts_linears.0         -           -        [32768, 63] + [1, 128]   [32768, 128]      float32
# synthesis.pts_linears.1.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.1         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.2.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.2         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.3.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.3         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.4.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.4         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.5.affine  -           -        [1, 128]                 [1, 3190]         float32
# synthesis.pts_linears.5         -           -        [32768, 191] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.6.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.6         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.7.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.7         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.output_linear.affine  -           -        [1, 128]                 [1, 1320]         float32
# synthesis.output_linear         -           -        [32768, 128] + [1, 128]  [32768, 4]        float32
# synthesis.pts_linears.0.affine  -           -        [1, 128]                 [1, 1910]         float32
# synthesis.pts_linears.0         -           -        [32768, 63] + [1, 128]   [32768, 128]      float32
# synthesis.pts_linears.1.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.1         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.2.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.2         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.3.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.3         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.4.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.4         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.5.affine  -           -        [1, 128]                 [1, 3190]         float32
# synthesis.pts_linears.5         -           -        [32768, 191] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.6.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.6         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.7.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.7         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.output_linear.affine  -           -        [1, 128]                 [1, 1320]         float32
# synthesis.output_linear         -           -        [32768, 128] + [1, 128]  [32768, 4]        float32
# synthesis.pts_linears.0.affine  -           -        [1, 128]                 [1, 1910]         float32
# synthesis.pts_linears.0         -           -        [32768, 63] + [1, 128]   [32768, 128]      float32
# synthesis.pts_linears.1.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.1         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.2.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.2         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.3.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.3         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.4.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.4         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.5.affine  -           -        [1, 128]                 [1, 3190]         float32
# synthesis.pts_linears.5         -           -        [32768, 191] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.6.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.6         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.pts_linears.7.affine  -           -        [1, 128]                 [1, 2560]         float32
# synthesis.pts_linears.7         -           -        [32768, 128] + [1, 128]  [32768, 128]      float32
# synthesis.output_linear.affine  -           -        [1, 128]                 [1, 1320]         float32
# synthesis.output_linear         -           -        [32768, 128] + [1, 128]  [32768, 4]        float32
# synthesis                       -           -        [4, 128]                 [4, 3, 128, 128]  float32
# ---                             ---         ---      ---                      ---               ---
# Total                           2975000     0        -                        -                 -
#
# Setting up PyTorch plugin "upfirdn2d_plugin"... Done.
#
# Discriminator  Parameters  Buffers  Input Shape       Output shape      Datatype
# ---            ---         ---      ---               ---               ---
# b32.fromrgb    2048        16       [4, 3, 32, 32]    [4, 512, 32, 32]  float16
# b32.skip       262144      16       [4, 512, 32, 32]  [4, 512, 16, 16]  float16
# b32.conv0      2359808     16       [4, 512, 32, 32]  [4, 512, 32, 32]  float16
# b32.conv1      2359808     16       [4, 512, 32, 32]  [4, 512, 16, 16]  float16
# b32            -           16       [4, 3, 32, 32]    [4, 512, 16, 16]  float16
# b16.skip       262144      16       [4, 512, 16, 16]  [4, 512, 8, 8]    float16
# b16.conv0      2359808     16       [4, 512, 16, 16]  [4, 512, 16, 16]  float16
# b16.conv1      2359808     16       [4, 512, 16, 16]  [4, 512, 8, 8]    float16
# b16            -           16       [4, 512, 16, 16]  [4, 512, 8, 8]    float16
# b8.skip        262144      16       [4, 512, 8, 8]    [4, 512, 4, 4]    float16
# b8.conv0       2359808     16       [4, 512, 8, 8]    [4, 512, 8, 8]    float16
# b8.conv1       2359808     16       [4, 512, 8, 8]    [4, 512, 4, 4]    float16
# b8             -           16       [4, 512, 8, 8]    [4, 512, 4, 4]    float16
# b4.mbstd       -           -        [4, 512, 4, 4]    [4, 513, 4, 4]    float32
# b4.conv        2364416     16       [4, 513, 4, 4]    [4, 512, 4, 4]    float32
# b4.fc          4194816     -        [4, 8192]         [4, 512]          float32
# b4.out         513         -        [4, 512]          [4, 1]            float32
# ---            ---         ---      ---               ---               ---
# Total          21507073    224      -                 -                 -
#
# Setting up augmentation...
# Distributing across 1 GPUs...
# Setting up training phases...
# Exporting sample images...
# Initializing logs...
# Training for 204 kimg...
#
# tick 0     kimg 0.0      time 9m 05s       sec/tick 1.6     sec/kimg 400.78  maintenance 543.3  cpumem 4.75   gpumem 9.13   augment 0.500
# Exporting sample video...
# Done rendering
# Done rendering
# Evaluating metrics for planes_128_t4_run1-None ...
# /content/hypernerfgan_env/lib/python3.8/site-packages/torch/utils/data/dataloader.py:478: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None/src/train.py:40: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "bool"):
# /content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None/src/train.py:42: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# /content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None/src/train.py:40: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "bool"):
# /content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None/src/train.py:42: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# /content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None/src/train.py:40: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "bool"):
# /content/drive/MyDrive/HyperNeRFGAN/experiments/planes_128_t4_run1-None/src/train.py:42: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# {"results": {"fid1k_full": 296.777597116322}, "metric": "fid1k_full", "total_time": 1316.8108048439026, "total_time_str": "21m 57s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000000.pkl", "timestamp": 1766509885.7088804}
# tick 1     kimg 4.0      time 53m 23s      sec/tick 324.4   sec/kimg 81.10   maintenance 2333.6 cpumem 5.09   gpumem 3.33   augment 0.500
# tick 2     kimg 8.0      time 58m 43s      sec/tick 320.2   sec/kimg 80.05   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 3     kimg 12.0     time 1h 04m 06s   sec/tick 322.6   sec/kimg 80.66   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 4     kimg 16.0     time 1h 09m 26s   sec/tick 319.8   sec/kimg 79.96   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 5     kimg 20.0     time 1h 14m 45s   sec/tick 319.4   sec/kimg 79.85   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 6     kimg 24.0     time 1h 20m 05s   sec/tick 319.1   sec/kimg 79.76   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 7     kimg 28.0     time 1h 25m 24s   sec/tick 318.9   sec/kimg 79.73   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 8     kimg 32.0     time 1h 30m 44s   sec/tick 319.8   sec/kimg 79.95   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 9     kimg 36.0     time 1h 36m 13s   sec/tick 329.4   sec/kimg 82.34   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 10    kimg 40.0     time 1h 41m 29s   sec/tick 316.0   sec/kimg 79.01   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 11    kimg 44.0     time 1h 46m 47s   sec/tick 317.6   sec/kimg 79.41   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 12    kimg 48.0     time 1h 52m 06s   sec/tick 318.8   sec/kimg 79.71   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 13    kimg 52.0     time 1h 57m 23s   sec/tick 317.6   sec/kimg 79.39   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 14    kimg 56.0     time 2h 02m 40s   sec/tick 316.1   sec/kimg 79.02   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 15    kimg 60.0     time 2h 07m 55s   sec/tick 315.3   sec/kimg 78.83   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 16    kimg 64.0     time 2h 13m 11s   sec/tick 316.2   sec/kimg 79.04   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 17    kimg 68.0     time 2h 18m 29s   sec/tick 317.3   sec/kimg 79.34   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 18    kimg 72.0     time 2h 23m 45s   sec/tick 316.6   sec/kimg 79.14   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 19    kimg 76.0     time 2h 29m 00s   sec/tick 314.8   sec/kimg 78.70   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 20    kimg 80.0     time 2h 34m 19s   sec/tick 318.1   sec/kimg 79.53   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 21    kimg 84.0     time 2h 39m 38s   sec/tick 319.0   sec/kimg 79.74   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 22    kimg 88.0     time 2h 44m 56s   sec/tick 318.6   sec/kimg 79.64   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 23    kimg 92.0     time 2h 50m 13s   sec/tick 316.8   sec/kimg 79.21   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 24    kimg 96.0     time 2h 55m 28s   sec/tick 314.9   sec/kimg 78.73   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 25    kimg 100.0    time 3h 00m 45s   sec/tick 316.3   sec/kimg 79.07   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 26    kimg 104.0    time 3h 06m 08s   sec/tick 323.3   sec/kimg 80.83   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 27    kimg 108.0    time 3h 11m 26s   sec/tick 318.2   sec/kimg 79.54   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 28    kimg 112.0    time 3h 16m 45s   sec/tick 318.9   sec/kimg 79.71   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 29    kimg 116.0    time 3h 22m 03s   sec/tick 317.3   sec/kimg 79.33   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 30    kimg 120.0    time 3h 27m 22s   sec/tick 319.0   sec/kimg 79.74   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 31    kimg 124.0    time 3h 32m 48s   sec/tick 325.7   sec/kimg 81.44   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 32    kimg 128.0    time 3h 38m 10s   sec/tick 322.5   sec/kimg 80.62   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 33    kimg 132.0    time 3h 43m 30s   sec/tick 319.4   sec/kimg 79.85   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 34    kimg 136.0    time 3h 48m 48s   sec/tick 318.0   sec/kimg 79.51   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 35    kimg 140.0    time 3h 54m 08s   sec/tick 319.9   sec/kimg 79.97   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 36    kimg 144.0    time 3h 59m 31s   sec/tick 322.7   sec/kimg 80.68   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 37    kimg 148.0    time 4h 04m 53s   sec/tick 322.5   sec/kimg 80.63   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 38    kimg 152.0    time 4h 10m 09s   sec/tick 316.0   sec/kimg 79.01   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 39    kimg 156.0    time 4h 15m 28s   sec/tick 318.1   sec/kimg 79.53   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 40    kimg 160.0    time 4h 20m 49s   sec/tick 321.3   sec/kimg 80.33   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 41    kimg 164.0    time 4h 26m 08s   sec/tick 318.7   sec/kimg 79.68   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 42    kimg 168.0    time 4h 31m 29s   sec/tick 320.8   sec/kimg 80.20   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 43    kimg 172.0    time 4h 36m 48s   sec/tick 318.8   sec/kimg 79.71   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 44    kimg 176.0    time 4h 42m 06s   sec/tick 318.3   sec/kimg 79.57   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 45    kimg 180.0    time 4h 47m 23s   sec/tick 317.0   sec/kimg 79.24   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 46    kimg 184.0    time 4h 52m 41s   sec/tick 317.5   sec/kimg 79.37   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 47    kimg 188.0    time 4h 58m 02s   sec/tick 321.2   sec/kimg 80.29   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 48    kimg 192.0    time 5h 03m 23s   sec/tick 321.4   sec/kimg 80.35   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 49    kimg 196.0    time 5h 08m 47s   sec/tick 323.9   sec/kimg 80.98   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# tick 50    kimg 200.0    time 5h 14m 08s   sec/tick 320.3   sec/kimg 80.08   maintenance 0.1    cpumem 5.09   gpumem 1.21   augment 0.500
# Exporting sample video...
# Done rendering
# Done rendering
# Evaluating metrics for planes_128_t4_run1-None ...
# {"results": {"fid1k_full": 169.16431667640097}, "metric": "fid1k_full", "total_time": 383.9732220172882, "total_time_str": "6m 24s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000200.pkl", "timestamp": 1766527184.612567}
# tick 51    kimg 204.0    time 5h 41m 37s   sec/tick 320.0   sec/kimg 80.09   maintenance 1329.5 cpumem 5.17   gpumem 1.56   augment 0.500
# Exporting sample video...
# Done rendering
# Done rendering
# Evaluating metrics for planes_128_t4_run1-None ...
# {"results": {"fid1k_full": 167.1400470075451}, "metric": "fid1k_full", "total_time": 404.714852809906, "total_time_str": "6m 45s", "num_gpus": 1, "snapshot_pkl": "network-snapshot-000204.pkl", "timestamp": 1766528774.24136}
#
# Exiting...
